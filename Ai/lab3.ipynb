# %%
def createMatrix(n):
    m=[]
    for i in range(n):
        row=[]
        row.append(0)
    m.append(row)
# Out:
# Running cells with '.venv (Python 3.14.6)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"e:/summer 25-26/.venv/bin/python.exe" -m pip install ipykernel -U --force-reinstall'
